# %% [markdown]
# <a href="https://colab.research.google.com/github/kdeepikasmcd/HTML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
gajularega=folium.Map(location=[18.1271, 83.4010])
gajularega
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#resize our map by using the branca library in Python
from branca.element import Figure
fig=Figure(width=550,height=350)
map1=folium.Map(location=[18.1271, 83.4010],zoom_start=12,min_zoom=8,max_zoom=14)
fig.add_child(map1)
map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
way1=[[16.77977597793576, 80.83907822542096],[16.679823561216512, 80.9379551779953],[16.690347334653936, 80.98190049025057],[16.690347334653936, 81.00936631041012],[16.685085520355727, 81.02584580250583],[16.711393142629014, 81.09725693492064],[17.042556833872013, 81.8278477511644],[17.1370678884732, 81.95968368793018],[17.205296004845675, 82.10250595275978],[17.226284215934864, 82.21786239742985],[17.252516127687766, 82.33321884209992],[17.268253485040066, 82.38265731838709],[17.34167670350769, 82.55294540337624],[17.68741733985935, 82.98690536189697],[17.692650755984417, 83.01986434608841],[17.816899485543733, 83.17916610301374],[17.837817087179033, 83.23684432534877],[17.835202521297283, 83.24508407139665],[17.903168743962986, 83.3796665901784],[17.93714209724098, 83.41262557436983],[17.97110893088474, 83.41811873840173],[18.01812914823356, 83.401639246306],[18.110551583569404, 83.3941404633269]]

from branca.element import Figure
fig=Figure(width=550,height=350)
f1=folium.FeatureGroup("Vehicle 1")
f2=folium.FeatureGroup("Vehicle 2")
map=folium.Map(location=[16.780001,80.849998],tiles='cartodbpositron')
line_1=folium.vector_layers.PolyLine(way1,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1)

f1.add_to(map)
folium.Marker(location=[18.106659,83.395554],popup='Default popup Marker1',tooltip='Click here to see more colcktower in vizianagaram',icon=folium.Icon(color='red',icon='none')).add_to(map)
folium.Marker(location=[17.994260208123844, 83.41503701534401],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Raghu Engineering College</strong>',icon=folium.Icon(color='green',prefix='glyphicon',icon='off')).add_to(map)
folium.Marker(location=[17.2827,82.4010],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Annavaram Temple</strong>',icon=folium.Icon(color='purple',prefix='fa',icon='anchor')).add_to(map)
folium.Marker(location=[17.004393,81.783325],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see rajahmundry bridge</strong>',icon=folium.Icon(color='green',prefix='glyphicon',icon='off')).add_to(map)
folium.Marker(location=[16.7792, 80.8715],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Sarswathi Temple</strong>',icon=folium.Icon(color='purple',prefix='fa',icon='anchor')).add_to(map)
folium.Marker(location=[25.5278,73.7265],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see jawahar navodaya vidyalaya</strong>',icon=folium.Icon(color='green',prefix='glyphicon',icon='off')).add_to(map)
folium.Marker(location=[22.2376, 68.9674],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see dwarka temple</strong>',icon=folium.Icon(color='green',prefix='glyphicon',icon='off')).add_to(map)
folium.Marker(location=[16.7194,81.0483],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see eluru college of engineering</strong>',icon=folium.Icon(color='green',prefix='glyphicon',icon='off')).add_to(map)
folium.Marker(location=[16.796562964548936, 81.13650574603199],popup='Default popup Marker1',tooltip='Click here to see Bharat Petroleum,Petrol Pump,Maa Petroleum',icon=folium.Icon(color='red',icon='none')).add_to(map)
folium.Marker(location=[16.7789, 81.2205],popup='Default popup Marker1',tooltip='Click here to see kfc gundugolanu andhra pradesh',icon=folium.Icon(color='red',icon='none')).add_to(map)
folium.Marker(location=[17.6615331,83.2104306],popup='Default popup Marker1',tooltip='Click here to see dmart in pedagantyada in vizag',icon=folium.Icon(color='red',icon='none')).add_to(map)

folium.Marker(location=[16.780001,80.849998],popup='Starting point',tooltip='Nuzvidu').add_to(map)
folium.Marker(location=[18.1271, 83.4010],popup='Destination',tooltip='Gajularega').add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
